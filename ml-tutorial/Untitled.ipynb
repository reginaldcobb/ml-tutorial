# %%
DATA_PATH = "C:/Users/regin/ml-tutorial/data"

# %%
from os import path
import pandas as pd

def load_nba_data(data_path=DATA_PATH):
    nba_data_path = path.join(data_path, "defense_2010-present.csv")
    return pd.read_csv(nba_data_path)

# %%
nba_data = load_nba_data()

# %%
nba_data.head()
# Out:
#                  TEAM  GP  W  L   MIN  OPPFGM  OPPFGA  OPPFG%  OPP3PM  OPP3PA  \
# 0       Orlando Magic  11  4  7  48.0    37.0    85.7    43.2    10.2    32.0
# 1           Utah Jazz  11  8  3  48.0    36.2    86.1    42.0     9.1    29.6
# 2  Los Angeles Lakers  11  9  2  48.5    36.6    86.9    42.2    10.3    32.9
# 3      Denver Nuggets  11  8  3  48.9    37.2    87.3    42.6    10.2    33.1
# 4      Indiana Pacers  11  7  4  48.5    37.7    85.7    44.0    11.1    30.5
#
#    ...  OPPREB  OPPAST  OPPTOV  OPPSTL  OPPBLK  OPPBLKA  OPPPF  OPPPFD  \
# 0  ...    46.2    21.7    14.4     6.3     4.5      6.7   19.7    19.5
# 1  ...    42.9    18.0    15.1     7.2     4.5      3.7   23.9    22.9
# 2  ...    43.5    23.2    17.0     7.8     4.0      7.4   20.2    20.9
# 3  ...    47.1    24.2    14.5     6.7     5.4      4.9   21.7    21.3
# 4  ...    43.6    23.4    16.7     6.3     4.5      5.5   19.5    22.8
#
#    OPPPTS  +/-
# 0    99.1 -0.3
# 1    99.5 -5.0
# 2   100.9 -9.9
# ...

# %%
nba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 26 columns):
# TEAM       300 non-null object
# GP         300 non-null int64
# W          300 non-null int64
# L          300 non-null int64
# MIN        300 non-null float64
# OPPFGM     300 non-null float64
# OPPFGA     300 non-null float64
# OPPFG%     300 non-null float64
# OPP3PM     300 non-null float64
# OPP3PA     300 non-null float64
# OPP3P%     300 non-null float64
# OPPFTM     300 non-null float64
# OPPFTA     300 non-null float64
# OPPFT%     300 non-null float64
# OPPOREB    300 non-null float64
# OPPDREB    300 non-null float64
# OPPREB     300 non-null float64
# OPPAST     300 non-null float64
# OPPTOV     300 non-null float64
# OPPSTL     300 non-null float64
# OPPBLK     300 non-null float64
# OPPBLKA    300 non-null float64
# OPPPF      300 non-null float64
# OPPPFD     300 non-null float64
# OPPPTS     300 non-null float64
# +/-        300 non-null float64
# ...

# %%
nba_data["TEAM"].value_counts()
# Out:
# Miami Heat                10
# Phoenix Suns              10
# Atlanta Hawks             10
# Houston Rockets           10
# Denver Nuggets            10
# Minnesota Timberwolves    10
# Washington Wizards        10
# Portland Trail Blazers    10
# Golden State Warriors     10
# Boston Celtics            10
# Detroit Pistons           10
# Los Angeles Lakers        10
# San Antonio Spurs         10
# Dallas Mavericks          10
# Cleveland Cavaliers       10
# Indiana Pacers            10
# Oklahoma City Thunder     10
# Sacramento Kings          10
# Utah Jazz                 10
# Chicago Bulls             10
# Toronto Raptors           10
# Milwaukee Bucks           10
# New York Knicks           10
# Orlando Magic             10
# Memphis Grizzlies         10
# Philadelphia 76ers        10
# Brooklyn Nets              8
# New Orleans Pelicans       7
# Charlotte Hornets          6
# Los Angeles Clippers       5
# LA Clippers                5
# Charlotte Bobcats          4
# ...

# %%
nba_data.describe()
# Out:
#                GP          W           L         MIN      OPPFGM      OPPFGA  \
# count  300.000000  300.00000  300.000000  300.000000  300.000000  300.000000
# mean    73.300000   36.65000   36.650000   48.351667   38.443333   84.565333
# std     21.321947   15.81078   15.814799    0.207624    2.216053    3.792176
# min      9.000000    2.00000    1.000000   48.000000   33.400000   75.800000
# 25%     82.000000   26.00000   27.000000   48.200000   37.000000   82.075000
# 50%     82.000000   39.00000   38.000000   48.400000   38.350000   84.300000
# 75%     82.000000   48.00000   48.000000   48.500000   39.700000   86.700000
# max     82.000000   73.00000   72.000000   49.400000   45.000000   96.700000
#
#            OPPFG%      OPP3PM      OPP3PA      OPP3P%  ...      OPPREB  \
# count  300.000000  300.000000  300.000000  300.000000  ...  300.000000
# mean    45.458000    8.723000   24.557667   35.496333  ...   43.330000
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
nba_data.hist(bins=10, figsize=(25, 15))
plt.show()
